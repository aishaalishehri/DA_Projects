# %%
#import libs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the file
df = pd.read_csv("/content/saudi-pro-league-transfers.csv")

# %%
#see the data
df.head(10)
# Out:
#       club_name         player_name   age            position  \
# 0  Al-Hilal SFC         Khaled Aziz  18.0  Defensive Midfield
# 1  Al-Hilal SFC       Sami Al-Jaber  27.0      Centre-Forward
# 2  Al-Hilal SFC  Fahad Al-Ghesheyan  26.0        Right Winger
# 3  Al-Hilal SFC   Saleh Al-Salloumi  37.0          Goalkeeper
# 4  Al-Hilal SFC       Elijah Litana  29.0         Centre-Back
# 5  Ittihad Club   Marzouq Al-Otaibi  24.0      Centre-Forward
# 6  Ittihad Club       Khalid Massad  28.0  Attacking Midfield
# 7  Ittihad Club        Ivan Malimon  21.0      Centre-Forward
# 8  Ittihad Club     Manaf Abushgeer  20.0       Left Midfield
# 9  Ittihad Club               Darci  31.0         Left Winger
#
#   club_involved_name            fee transfer_movement transfer_period  \
# 0            Unknown              ?                in          Summer
# 1             Wolves  loan transfer               out          Summer
# 2           Al-Nassr              -               out          Summer
# 3            Retired              -               out          Summer
# 4            Retired              -               out          Summer
# 5          Al-Shabab         €2.00m                in          Summer
# 6            Al-Ahli  free transfer                in          Summer
# 7         Edessaikos  free transfer                in          Summer
# 8     Ittihad C. U23              -                in          Summer
# 9        Antalyaspor              ?               out          Summer
#
#                  league_name     season       country
# 0  Saudi Professional League  2000/2001  Saudi Arabia
# 1  Saudi Professional League  2000/2001  Saudi Arabia
# 2  Saudi Professional League  2000/2001  Saudi Arabia
# 3  Saudi Professional League  2000/2001  Saudi Arabia
# 4  Saudi Professional League  2000/2001  Saudi Arabia
# 5  Saudi Professional League  2000/2001  Saudi Arabia
# 6  Saudi Professional League  2000/2001  Saudi Arabia
# 7  Saudi Professional League  2000/2001  Saudi Arabia
# 8  Saudi Professional League  2000/2001  Saudi Arabia
# 9  Saudi Professional League  2000/2001  Saudi Arabia

# %%
#Top 10 transfers clubs
df['club_name'].value_counts().head(10)
# Out:
# Ittihad Club     640
# Al-Ahli SFC      596
# Al-Nassr FC      567
# Al-Shabab FC     542
# Al-Hilal SFC     541
# Al-Raed SFC      497
# Al-Ettifaq FC    472
# Al-Taawoun FC    431
# Al-Faisaly FC    428
# Al-Fateh SC      377
# Name: club_name, dtype: int64

# %%
#Top 5 clubs in attracting players
df[df['transfer_movement'] == 'in']['club_name'].value_counts().head(5)
# Out:
# Ittihad Club    317
# Al-Ahli SFC     296
# Al-Nassr FC     281
# Al-Hilal SFC    266
# Al-Shabab FC    263
# Name: club_name, dtype: int64

# %%
#Top five clubs in Alienate players
df[df['transfer_movement'] == 'out']['club_name'].value_counts().head(5)
# Out:
# Ittihad Club    323
# Al-Ahli SFC     300
# Al-Nassr FC     286
# Al-Shabab FC    279
# Al-Hilal SFC    275
# Name: club_name, dtype: int64

# %%
#Change type of fee column and remove any string by using Lambda Function them applied it on fee.
re_fun = lambda x: pd.to_numeric(str(x).replace('€', '').replace('m', ''), errors='coerce')

# Apply the lambda function to the 'fee' column
df['fee'] = df['fee'].apply(re_fun)

# %%
df[df['transfer_movement'] == 'in'].nlargest(5, 'fee')
# Out:
#          club_name              player_name   age            position  \
# 7652  Al-Hilal SFC                   Neymar  31.0         Left Winger
# 7653  Al-Hilal SFC                   Malcom  26.0        Right Winger
# 7654  Al-Hilal SFC              Rúben Neves  26.0  Defensive Midfield
# 7596  Ittihad Club                  Fabinho  29.0  Defensive Midfield
# 7655  Al-Hilal SFC  Sergej Milinković-Savić  28.0    Central Midfield
#
#      club_involved_name   fee transfer_movement transfer_period  \
# 7652           Paris SG  90.0                in          Summer
# 7653         Zenit S-Pb  60.0                in          Summer
# 7654             Wolves  55.0                in          Summer
# 7596          Liverpool  46.7                in          Summer
# 7655              Lazio  40.0                in          Summer
#
#                     league_name     season       country
# 7652  Saudi Professional League  2023/2024  Saudi Arabia
# 7653  Saudi Professional League  2023/2024  Saudi Arabia
# 7654  Saudi Professional League  2023/2024  Saudi Arabia
# 7596  Saudi Professional League  2023/2024  Saudi Arabia
# 7655  Saudi Professional League  2023/2024  Saudi Arabia

# %%
df[df['transfer_movement'] == 'out'].nlargest(5, 'fee')
# Out:
#           club_name             player_name   age            position  \
# 2870   Al-Hilal SFC            Thiago Neves  30.0  Attacking Midfield
# 1988  Al-Ettifaq FC         Yahya Al-Shehri  23.0  Attacking Midfield
# 1490   Al-Hilal SFC            Thiago Neves  26.0  Attacking Midfield
# 3046   Al-Shabab FC  Naif Ahmed Taib Hazazi  26.0      Centre-Forward
# 7643   Al-Shabab FC         Aaron Boupendza  26.0      Centre-Forward
#
#      club_involved_name   fee transfer_movement transfer_period  \
# 2870          Al-Jazira  11.0               out          Summer
# 1988           Al-Nassr   9.8               out          Summer
# 1490         Fluminense   7.0               out          Winter
# 3046           Al-Nassr   6.8               out          Summer
# 7643         Cincinnati   6.5               out          Summer
#
#                     league_name     season       country
# 2870  Saudi Professional League  2015/2016  Saudi Arabia
# 1988  Saudi Professional League  2013/2014  Saudi Arabia
# 1490  Saudi Professional League  2011/2012  Saudi Arabia
# 3046  Saudi Professional League  2015/2016  Saudi Arabia
# 7643  Saudi Professional League  2023/2024  Saudi Arabia

# %%
import matplotlib.pyplot as plt

# Data for incoming transfers
Top_n = df[df['transfer_movement'] == 'in'].nlargest(5, 'fee')
# Data for outgoing transfers
Top_o = df[df['transfer_movement'] == 'out'].nlargest(5, 'fee')

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot incoming transfers with data labels
bars1 = ax1.bar(Top_n['player_name'], Top_n['fee'], color='green')
ax1.set_title('Top 5 Deals In')
ax1.set_ylabel('Fee Cost')
ax1.set_xlabel('Player Name')
ax1.set_xticklabels(Top_n['player_name'], rotation=90, ha='right')  # Rotate x-axis labels for better readability

# Plot outgoing transfers with data labels
bars2 = ax2.bar(Top_o['player_name'], Top_o['fee'], color='red')
ax2.set_title('Top 5 Deals Out')
ax2.set_ylabel('Fee Cost')
ax2.set_xlabel('Player Name')
ax2.set_xticklabels(Top_o['player_name'], rotation=90, ha='right')  # Rotate x-axis labels for better readability


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-32-43817fb10a3f>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Top_n['player_name'], rotation=90, ha='right')  # Rotate x-axis labels for better readability
# <ipython-input-32-43817fb10a3f>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(Top_o['player_name'], rotation=90, ha='right')  # Rotate x-axis labels for better readability

# %%
#First try if is it work group the data by club name, then add 2 column number of deals, avg_prices with the right function
#then jus add like a filter to only top 5
df.groupby(['club_name']).agg(
    num_deals=('fee', 'count'),
    avg_price=('fee', 'mean')
).nlargest(5, 'num_deals').reset_index()
# Out:
#       club_name  num_deals  avg_price
# 0  Al-Hilal SFC         48   9.443958
# 1   Al-Nassr FC         42   5.865238
# 2   Al-Ahli SFC         40   5.994250
# 3  Ittihad Club         38   5.313158
# 4  Al-Shabab FC         27   3.478148

# %%
#Add the above result in df
top_5_clubs = df.groupby(['club_name']).agg(
    num_deals=('fee', 'count'),
    avg_price=('fee', 'mean')
).nlargest(5, 'num_deals').reset_index()

# Create bar chart for num_deals column
plt.figure(figsize=(10, 6))
plt.bar(top_5_clubs['club_name'], top_5_clubs['num_deals'], color='green')
plt.title('Top 5 Clubs with the Highest Number of Deals')
plt.xlabel('Club Name')
plt.ylabel('Number of Deals')
plt.tight_layout()
plt.show()

# %%
top_5_clubs2 = df.groupby(['club_name']).agg(
    num_deals=('fee', 'count'),
    avg_price=('fee', 'mean')
).nlargest(5, 'avg_price').reset_index()

# Create the bar chart for avrg price column
plt.figure(figsize=(10, 6))
plt.bar(top_5_clubs2['club_name'], top_5_clubs2['avg_price'], color='green')
plt.title('Top 5 Clubs with Expensive Avg of Deals')
plt.xlabel('Club Name')
plt.ylabel('Avg price (m)')
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Define the conditions and  ratings
conditions = [
    (df['fee'] >= 0) & (df['fee'] < 10),
    (df['fee'] >= 10) & (df['fee'] < 35),
    (df['fee'] >= 35)
]

ratings = ['Low', 'Mid', 'High']

#Create a new 'rating_transfer' column based on the conditions and ratings
df['rating_deal'] = np.select(conditions, ratings, default=np.nan)

# %%
#Split the season column to reach the 1st year only
df['year'] = df['season'].apply(lambda x: x.split('/')[0])

# %%
Total_per_year= df.groupby('year')['fee'].sum()

# Create a line plot for the total fee per year
Total_per_year.plot(kind='line', marker='o', xlabel='Year', ylabel='Price in Million', title='Total cost per Year', figsize=(10, 6), color='green')

# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.groupby(['year','transfer_period'])['fee'].sum()
# Out:
# year  transfer_period
# 2000  Summer               4.00
#       Winter               0.00
# 2001  Summer               0.00
#       Winter               0.00
# 2002  Summer               0.00
#       Winter               1.10
# 2003  Summer               2.00
#       Winter               0.00
# 2004  Summer               0.00
#       Winter               0.00
# 2005  Summer              17.60
#       Winter               1.00
# 2006  Summer               3.70
#       Winter              10.00
# 2007  Summer               6.14
#       Winter               0.00
# 2008  Summer               8.25
#       Winter               8.60
# 2009  Summer              11.50
#       Winter               0.00
# 2010  Summer               5.26
#       Winter               0.00
# 2011  Summer              28.03
#       Winter               7.00
# 2012  Summer              21.00
#       Winter              10.00
# 2013  Summer              40.10
#       Winter               1.20
# 2014  Summer              14.55
#       Winter               3.75
# 2015  Summer              48.61
#       Winter               2.65
# 2016  Summer              17.50
#       Winter               2.00
# 2017  Summer              17.60
#       Winter              11.20
# 2018  Summer             116.40
#       Winter              68.73
# 2019  Summer              89.75
#       Winter               7.20
# 2020  Summer              73.46
#       Winter               3.50
# 2021  Summer              57.79
#       Winter              34.14
# 2022  Summer              31.94
#       Winter               4.70
# 2023  Summer             619.23
#       Winter               0.00
# 2024  Summer               0.00
# Name: fee, dtype: float64

# %%
# Group the data by year and transfer period and calculate the total fee per period
Total_per_period = df.groupby(['year', 'transfer_period'])['fee'].sum()

# Unstack the multi-index to separate transfer periods into columns
Total_per_period_unstacked = Total_per_period.unstack()

# Create subplots for each transfer period
fig, ax = plt.subplots(figsize=(10, 6))

# Define colors for each transfer period
colors = ['green', 'red']  # Add more colors if needed

# Plot each transfer period with a different color
for i, period in enumerate(Total_per_period_unstacked.columns):
    ax.plot(Total_per_period_unstacked.index, Total_per_period_unstacked[period], marker='o', label=period, color=colors[i])

# Set labels and title
ax.set_xlabel('Year')
ax.set_ylabel('Total Fee in Million')
ax.set_title('Total Fee per Period')
ax.legend(title='Period')

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#It just the way how I work in next cell
#df.groupby(['club_name']).agg(
    #num_deals=('fee', 'count'),
    #avg_price=('fee', 'mean'),
    #percent=()
#).nlargest(5, 'avg_price').reset_index()

# %%
# Calculate total number of deals
t_num_deals = df['fee'].count()

# Group the data by club_name and calculate num_deals and avg_price
grouped_data = df.groupby(['club_name']).agg(
    num_deals=('fee', 'count')
)

# Calculate percentage of num_deals for each club
grouped_data['percent'] = (grouped_data['num_deals'].round() / t_num_deals) * 100
grouped_data['percentage'] = (grouped_data['percent']).astype(int).astype(str) + '%'
grouped_data
# Out:
#                  num_deals    percent percentage
# club_name
# Abha Club                1   0.374532         0%
# Al-Adalah FC             0   0.000000         0%
# Al-Ahli SFC             40  14.981273        14%
# Al-Ain FC                1   0.374532         0%
# Al-Ansar                 0   0.000000         0%
# Al-Batin FC              2   0.749064         0%
# Al-Ettifaq FC           12   4.494382         4%
# Al-Faisaly FC            7   2.621723         2%
# Al-Fateh SC              9   3.370787         3%
# Al-Fayha FC              8   2.996255         2%
# Al-Hazem SC              3   1.123596         1%
# Al-Hilal SFC            48  17.977528        17%
# Al-Nahdah FC             0   0.000000         0%
# Al-Nassr FC             42  15.730337        15%
# Al-Okhdood Club          1   0.374532         0%
# Al-Orobah FC             0   0.000000         0%
# Al-Qadsiah FC            4   1.498127         1%
# Al-Raed SFC              2   0.749064         0%
# Al-Riyadh SC             0   0.000000         0%
# Al-Shabab FC            27  10.112360        10%
# Al-Shoalah FC            0   0.000000         0%
# Al-Taawoun FC            7   2.621723         2%
# Al-Tai FC                1   0.374532         0%
# Al-Watani                0   0.000000         0%
# Al-Wehda FC             10   3.745318         3%
# Damac FC                 3   1.123596         1%
# Hajer Club               0   0.000000         0%
# Ittihad Club            38  14.232210        14%
# Khaleej FC               1   0.374532         0%
# Najran SC                0   0.000000         0%
# Ohod Club                0   0.000000         0%

# %%
percent_df = grouped_data.nlargest(10,'percent').reset_index()

# %%
percent_df.drop(columns=['percent'], inplace=True)

# %%
percent_df
# Out:
#        club_name  num_deals percentage
# 0   Al-Hilal SFC         48        17%
# 1    Al-Nassr FC         42        15%
# 2    Al-Ahli SFC         40        14%
# 3   Ittihad Club         38        14%
# 4   Al-Shabab FC         27        10%
# 5  Al-Ettifaq FC         12         4%
# 6    Al-Wehda FC         10         3%
# 7    Al-Fateh SC          9         3%
# 8    Al-Fayha FC          8         2%
# 9  Al-Faisaly FC          7         2%

# %%
# Create a figure and axis object
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the percentage as a line chart
ax1.bar(percent_df['club_name'], percent_df['num_deals'], color='green', label='Number of Deals')
ax1.set_ylabel('Number of deals', color='black')

# Reverse the order of the values for percentage
percent_df_reverse = percent_df.iloc[::-1]

# Create a secondary y-axis for num_deals as a clustered column chart
ax2 = ax1.twinx()
ax2.plot(percent_df_reverse['percentage'], marker='o', color='red', label='Percentage')
ax2.set_ylabel('Percentage', color='black')
ax2.set_xlabel('Club Name')
ax2.set_title('Number of Deals and its Percentage for each Club')

# Show legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper center')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['age'], df['rating_deal'])

# Perform chi-square test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Calculate Cramer's V
n = contingency_table.sum().sum() # Total number of observations
phi2 = chi2 / n
r, k = contingency_table.shape
cramer_v = np.sqrt(phi2 / min((r - 1), (k - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p)
print("Cramer's V:", cramer_v)

#Overall, based on the p-value and Cramer's V, we would conclude that
#there is no significant association between the two categorical variables.
# Out:
# Chi-square statistic: 85.42993665564504
# P-value: 0.43600993711102815
# Cramer's V: 0.06059733345328147

# %%
df
# Out:
#           club_name         player_name   age            position  \
# 0      Al-Hilal SFC         Khaled Aziz  18.0  Defensive Midfield
# 1      Al-Hilal SFC       Sami Al-Jaber  27.0      Centre-Forward
# 2      Al-Hilal SFC  Fahad Al-Ghesheyan  26.0        Right Winger
# 3      Al-Hilal SFC   Saleh Al-Salloumi  37.0          Goalkeeper
# 4      Al-Hilal SFC       Elijah Litana  29.0         Centre-Back
# ...             ...                 ...   ...                 ...
# 7853    Al-Raed SFC        Mamadou Loum  27.0  Defensive Midfield
# 7854  Al-Ettifaq FC    Rayan Al-Bloushi  23.0      Centre-Forward
# 7855  Al-Taawoun FC              Flávio  28.0    Central Midfield
# 7856  Al-Taawoun FC       Muath Faquihi  22.0           Left-Back
# 7857     Khaleej FC  Abdalellah Hawsawi   NaN            Midfield
#
#      club_involved_name  fee transfer_movement transfer_period  \
# 0               Unknown  NaN                in          Summer
# 1                Wolves  NaN               out          Summer
# 2              Al-Nassr  NaN               out          Summer
# 3               Retired  NaN               out          Summer
# 4               Retired  NaN               out          Summer
# ...                 ...  ...               ...             ...
# 7853           FC Porto  NaN               out          Summer
# 7854            Al-Safa  NaN                in          Summer
# 7855        Trabzonspor  NaN               out          Summer
# 7856           Al-Hilal  NaN               out          Summer
# 7857     Ittihad C. U23  NaN               out          Summer
#
#                     league_name     season       country rating_deal  year
# 0     Saudi Professional League  2000/2001  Saudi Arabia         nan  2000
# 1     Saudi Professional League  2000/2001  Saudi Arabia         nan  2000
# 2     Saudi Professional League  2000/2001  Saudi Arabia         nan  2000
# 3     Saudi Professional League  2000/2001  Saudi Arabia         nan  2000
# 4     Saudi Professional League  2000/2001  Saudi Arabia         nan  2000
# ...                         ...        ...           ...         ...   ...
# 7853  Saudi Professional League  2024/2025  Saudi Arabia         nan  2024
# 7854  Saudi Professional League  2024/2025  Saudi Arabia         nan  2024
# 7855  Saudi Professional League  2024/2025  Saudi Arabia         nan  2024
# 7856  Saudi Professional League  2024/2025  Saudi Arabia         nan  2024
# 7857  Saudi Professional League  2024/2025  Saudi Arabia         nan  2024
#
# [7858 rows x 13 columns]

# %%
deals_avg = df.groupby(['rating_deal']).agg(
    avr_deal=('fee', 'mean')
).reset_index()
deals_avg = deals_avg.drop(3)

# %%
deals_avg
# Out:
#   rating_deal   avr_deal
# 0        High  54.450000
# 1         Low   2.978292
# 2         Mid  17.604286

# %%
# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(deals_avg['rating_deal'], deals_avg['avr_deal'], color='green')
plt.title('Average price per rating')
plt.xlabel('Rating')
plt.ylabel('Avg Price (m)')
plt.tight_layout()

# Show the plot
plt.show()
